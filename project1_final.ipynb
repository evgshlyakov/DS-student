# %% [markdown]
# # Результат ревью V2:
#
# Евгений, после правки финального вывода красных комментариев в твоей работе более нет. Соответственно нет и никаких вопросов/моментов/комментариев, мешающих принять твой проект у меня прямо сейчас.
#
# ПРОЕКТ ПРИНЯТ!
#
# Желаю тебе успехов в учёбе, желаю, чтобы проекты сдавались или сразу, или после первой итерации! Удачи!
#
# p.s Повторюсь, что для дальнейшего совершенствования в использовании groupby, понимании расширенных концептов использования pivot_table, crosstab и далее я очень рекомендую обратить внимание на следующий ресурс: https://dfedorov.spb.ru/pandas/.
#
# p.p.s Я тебе на твой адрес эл/почты сейчас вышлю некоторые материалы из своей электронной библиотеки - надеюсь они будут тебе полезными в учёбе.

# %% [markdown]
# Привет Евгений!
#
# Меня зовут Александр Непомнящий и я буду проверять твой проект. Предлагаю общаться на «ты» :))) Но, если это не удобно - мы вполне можем перейти на вы".
#
# Вкратце обо мне: я работаю в сфере информационных технологий, аналитика (анализ) данных - это и мой рабочий функционал и личная, интересная мне область для саморазвития. Используемый стек: python, pandas, графические библиотеки matplotlib/seaborn/plotly. Сфера применения: маркетинговая аналитика в медицинской клинике. Если вдруг есть вопрос – что делает аналитик в коммерческой медицине – то вот короткий ответ. Самый главный вопрос, на который мы хотим получить ответ (и который в дальнейшем приведёт к перераспределению рекламного бюджета, плюс напрямую повлияет на разработку и предложению рынку новых лечебных программ) - это КТО ОН, НАШ КЛИЕНТ? Фактически это задача (на нашем внутреннем языке формулируется как построение и анализ «ПОРТРЕТА КЛИЕНТА»). Визуализируем и пытаемся придать смысл половозрастным данным наших клиентов, кто из какого региона и в какие времена года к нам приезжает. Учитываем количество приездов. Учитываем на какую программу этот конкретный клиент приехал в первый раз и как в дальнейшем меняются его предпочтения. Пытаемся построить модель оттока и спрогнозировать, когда клиент уйдёт в отток. Смотрим цифры (суммы трат клиентов на отдельных группах медицинских программ). Анализируем медицинские услуги, которые входят в путёвку, а также что, в каких количествах и на какую сумму клиент покупает дополнительно. Очень вкратце как-то так.
#
# Теперь к сути: основная цель моей проверки - пройти по шагам, по логике твоего решения и обсудить те моменты, которые можно изменить, улучшить, довести до идеала. Такой формат работы двух программистов (аналитиков) ты или уже встречал(а), или встретишь на своей новой работе. Кто-то такой процесс называет "код-ревью", ну а как по мне, так это обмен опытом двух коллег, когда каждый из нас становиться лучше в процессе дискуссии.
#
# Свои мысли, советы, комментарии и вопросы я буду оставлять в текстовых ячейках (markdown) ПОД твоим кодом.
# Для твоего удобства все эти заметки будут "цветными", как на примерах ниже:
#
# "Зелеными" комментариями я буду отмечать твой элегантный ("красивый") код и/или удачные решения, на которые ты можешь смело опираться в будущих проектах.
# <div class="alert alert-success">
# <b>Отлично! 👍</b>
#
# Отличная находка, элегантный код ...</div>
#
# "Жёлтые" комментарии - это мои размышления, предложения, что-то, что в следующий раз можно сделать по-другому. "Жёлтые" комментарии не требуют твоих правок в проекте и их наличие НИКАК не повлияет на результат моей проверки. Но я искренне верю, что наш двусторонний диалог под "желтым" комментарием - это то, от чего твой проект только выиграет.
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Здесь я бы предложил использовать .... Мои аргументы в пользу этого ...</div>
#
# "Красные" комментарий будут появляться, когда что-то пойдёт не так: например, код будет выдавать ошибку. Или, когда в проекте не будет ответов на основные вопросы, ради которых весь анализ и выполнялся. "Красные" комментарии необходимо будет исправить, прежде чем я смогу принять проект.
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# В этой ячейке код работает не так как задумано ...</div>
#
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Это поможет мне оперативно выполнить повторную проверку твоего проекта.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом, лучше всего в новой ячейке, сразу под моим комментарием. Если для своих комментариев ты будешь использовать какой-то заметный цвет, то мне будет легче отследить твои изменения, например так:
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Текст твоего комментария ...</font>
# </div>
#
# Ну и наконец информируй меня в том случае, если по твоему проекту подходит дедлайн! В таком случае я приложу усилия, чтобы ты сдал(а) его вовремя; буду оперативно, в приоритете проверять итерации ревью, а также отвечать на твои вопросы, если этого будет требовать ситуация.
#
# **Распространенные типичные недочёты в проектах студентов:**
#
# <div class="alert alert-danger" ❌>
# Неработоспособный код. Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании.</div>
#
# <div class="alert alert-danger" ❌>
# Проект не структурирован. В проекте должна быть структура, т.е. названия разделов и подразделов должны быть записаны в ячейках Markdown.</div>
#
# <div class="alert alert-warning" 👉 >
# Отсутствие описания, целей проекта, его задач, выводов. В описании должны быть озвучены поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.</div>
#
# <div class="alert alert-warning" 👉 >
# "Длинный код". Код и и комментарии, которые прячутся за правым концом ячейки нужно переносить на новую строку. Твои будущие коллеги не оценят необходимость постоянного скроллинга. Согласно PEP8: https://www.python.org/dev/peps/pep-0008/ длина строки не должна превышать 79 символов.</div>
#
# <div class="alert alert-warning" 👉 >
# Твои коллеги ценят и твое и своё время, поэтому "подсвечивай" свои комментарии в ячейках Markdown. Подробнее про синтаксис Markdown, с примерами, можно почитать здесь: https://paulradzkov.com/2014/markdown_cheatsheet/?</div>

# %% [markdown]
# # Исследование надежности заемщиков

# %% [markdown]
# Во второй части проекта вы выполните шаги 3 и 4. Их вручную проверит ревьюер.
# Чтобы вам не пришлось писать код заново для шагов 1 и 2, мы добавили авторские решения в ячейки с кодом.

# %% [markdown]
# ## Откройте таблицу и изучите общую информацию о данных

# %% [markdown]
# **Задание 1. Импортируйте библиотеку pandas. Считайте данные из csv-файла в датафрейм и сохраните в переменную `data`. Путь к файлу:**
#
# `/datasets/data.csv`

# %%
import pandas as pd

try:
    data = pd.read_csv('/datasets/data.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/data.csv')

# %% [markdown]
# **Задание 2. Выведите первые 20 строчек датафрейма `data` на экран.**

# %%
data.head(20)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# ...

# %% [markdown]
# **Задание 3. Выведите основную информацию о датафрейме с помощью метода `info()`.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Удаление пропусков

# %% [markdown]
# **Задание 4. Выведите количество пропущенных значений для каждого столбца. Используйте комбинацию двух методов.**

# %%
data.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# **Задание 5. В двух столбцах есть пропущенные значения. Один из них — `days_employed`. Пропуски в этом столбце вы обработаете на следующем этапе. Другой столбец с пропущенными значениями — `total_income` — хранит данные о доходах. На сумму дохода сильнее всего влияет тип занятости, поэтому заполнить пропуски в этом столбце нужно медианным значением по каждому типу из столбца `income_type`. Например, у человека с типом занятости `сотрудник` пропуск в столбце `total_income` должен быть заполнен медианным доходом среди всех записей с тем же типом.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['total_income'].isna()), 'total_income'] = \
    data.loc[(data['income_type'] == t), 'total_income'].median()

# %% [markdown]
# ### Обработка аномальных значений

# %% [markdown]
# **Задание 6. В данных могут встречаться артефакты (аномалии) — значения, которые не отражают действительность и появились по какой-то ошибке. таким артефактом будет отрицательное количество дней трудового стажа в столбце `days_employed`. Для реальных данных это нормально. Обработайте значения в этом столбце: замените все отрицательные значения положительными с помощью метода `abs()`.**

# %%
data['days_employed'] = data['days_employed'].abs()

# %% [markdown]
# **Задание 7. Для каждого типа занятости выведите медианное значение трудового стажа `days_employed` в днях.**

# %%
data.groupby('income_type')['days_employed'].agg('median')
# Out:
# income_type
# безработный        366413.652744
# в декрете            3296.759962
# госслужащий          2689.368353
# компаньон            1547.382223
# пенсионер          365213.306266
# предприниматель       520.848083
# сотрудник            1574.202821
# студент               578.751554
# Name: days_employed, dtype: float64

# %% [markdown]
# У двух типов (безработные и пенсионеры) получатся аномально большие значения. Исправить такие значения сложно, поэтому оставьте их как есть. Тем более этот столбец не понадобится вам для исследования.

# %% [markdown]
# **Задание 8. Выведите перечень уникальных значений столбца `children`.**

# %%
data['children'].unique()
# Out:
# array([ 1,  0,  3,  2, -1,  4, 20,  5])

# %% [markdown]
# **Задание 9. В столбце `children` есть два аномальных значения. Удалите строки, в которых встречаются такие аномальные значения из датафрейма `data`.**

# %%
# data = data[(data['children'] != -1) & (data['children'] != 20)]
# data = data.drop(data.query('children in [-1, 20]').index)
data = data.query('children not in [-1, 20]')
data
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1    8437.673028         42    высшее             0
# 1             1    4024.803754         36   среднее             1
# 2             0    5623.422610         33   Среднее             1
# 3             3    4124.747207         32   среднее             1
# 4             0  340266.072047         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21520         1    4529.316663         43   среднее             1
# 21521         0  343937.404131         67   среднее             1
# 21522         1    2113.346888         38   среднее             1
# 21523         3    3112.481705         38   среднее             1
# 21524         2    1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# ...

# %% [markdown]
# **Задание 10. Ещё раз выведите перечень уникальных значений столбца `children`, чтобы убедиться, что артефакты удалены.**

# %%
data['children'].unique()
# Out:
# array([1, 0, 3, 2, 4, 5])

# %% [markdown]
# ### Удаление пропусков (продолжение)

# %% [markdown]
# **Задание 11. Заполните пропуски в столбце `days_employed` медианными значениями по каждого типа занятости `income_type`.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['days_employed'].isna()), 'days_employed'] = \
    data.loc[(data['income_type'] == t), 'days_employed'].median()

# %% [markdown]
# **Задание 12. Убедитесь, что все пропуски заполнены. Проверьте себя и ещё раз выведите количество пропущенных значений для каждого столбца с помощью двух методов.**

# %%
data.isna().sum()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# **Задание 13. Замените вещественный тип данных в столбце `total_income` на целочисленный с помощью метода `astype()`.**

# %%
data['total_income'] = data['total_income'].astype(int)

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# **Задание 14. Выведите на экран количество строк-дубликатов в данных. Если такие строки присутствуют, удалите их.**

# %%
data.duplicated().sum()
# Out:
# 54

# %%
data = data.drop_duplicates()

# %% [markdown]
# **Задание 15. Обработайте неявные дубликаты в столбце `education`. В этом столбце есть одни и те же значения, но записанные по-разному: с использованием заглавных и строчных букв. Приведите их к нижнему регистру. Проверьте остальные столбцы.**

# %%
data['education'] = data['education'].str.lower()

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# **Задание 16. На основании диапазонов, указанных ниже, создайте в датафрейме `data` столбец `total_income_category` с категориями:**
#
# - 0–30000 — `'E'`;
# - 30001–50000 — `'D'`;
# - 50001–200000 — `'C'`;
# - 200001–1000000 — `'B'`;
# - 1000001 и выше — `'A'`.
#
#
# **Например, кредитополучателю с доходом 25000 нужно назначить категорию `'E'`, а клиенту, получающему 235000, — `'B'`. Используйте собственную функцию с именем `categorize_income()` и метод `apply()`.**

# %%
def categorize_income(income):
    try:
        if 0 <= income <= 30000:
            return 'E'
        elif 30001 <= income <= 50000:
            return 'D'
        elif 50001 <= income <= 200000:
            return 'C'
        elif 200001 <= income <= 1000000:
            return 'B'
        elif income >= 1000001:
            return 'A'
    except:
        pass

# %%
data['total_income_category'] = data['total_income'].apply(categorize_income)

# %% [markdown]
# **Задание 17. Выведите на экран перечень уникальных целей взятия кредита из столбца `purpose`.**

# %%
data['purpose'].unique()
# Out:
# array(['покупка жилья', 'приобретение автомобиля',
#        'дополнительное образование', 'сыграть свадьбу',
#        'операции с жильем', 'образование', 'на проведение свадьбы',
#        'покупка жилья для семьи', 'покупка недвижимости',
#        'покупка коммерческой недвижимости', 'покупка жилой недвижимости',
#        'строительство собственной недвижимости', 'недвижимость',
#        'строительство недвижимости', 'на покупку подержанного автомобиля',
#        'на покупку своего автомобиля',
#        'операции с коммерческой недвижимостью',
#        'строительство жилой недвижимости', 'жилье',
#        'операции со своей недвижимостью', 'автомобили',
#        'заняться образованием', 'сделка с подержанным автомобилем',
#        'получение образования', 'автомобиль', 'свадьба',
#        'получение дополнительного образования', 'покупка своего жилья',
#        'операции с недвижимостью', 'получение высшего образования',
#        'свой автомобиль', 'сделка с автомобилем',
# ...

# %% [markdown]
# **Задание 18. Создайте функцию, которая на основании данных из столбца `purpose` сформирует новый столбец `purpose_category`, в который войдут следующие категории:**
#
# - `'операции с автомобилем'`,
# - `'операции с недвижимостью'`,
# - `'проведение свадьбы'`,
# - `'получение образования'`.
#
# **Например, если в столбце `purpose` находится подстрока `'на покупку автомобиля'`, то в столбце `purpose_category` должна появиться строка `'операции с автомобилем'`.**
#
# **Используйте собственную функцию с именем `categorize_purpose()` и метод `apply()`. Изучите данные в столбце `purpose` и определите, какие подстроки помогут вам правильно определить категорию.**

# %%
def categorize_purpose(row):
    try:
        if 'автом' in row:
            return 'операции с автомобилем'
        elif 'жил' in row or 'недвиж' in row:
            return 'операции с недвижимостью'
        elif 'свад' in row:
            return 'проведение свадьбы'
        elif 'образов' in row:
            return 'получение образования'
    except:
        return 'нет категории'

# %%
data['purpose_category'] = data['purpose'].apply(categorize_purpose)

# %% [markdown]
# ## Исследуйте данные и ответьте на вопросы

# %% [markdown]
# **Задание 19. Есть ли зависимость между количеством детей и возвратом кредита в срок?**

# %% [markdown]
#    *Для исследования зависимости количества детей и возврата кредита создадим новую таблицу из следующих колонок таблицы `'data`', которые нам потребуются для ответа на вопрос задания:*
#
#    * `'children`'
#    * `'debt`'
#
#
#   *Также возьмём из таблицы `'data`' ещё одну любую колонку, в которую позже запишем классификации долга словами, для последующей наглядности при выводе группировок и сводных таблиц*

# %%
data_an = data[['children', 'debt', 'income_type']] # создаём таблицу из data c 3-мя столбцами

data_an = data_an.rename(columns = {'income_type': 'debt_category'}) # переименуем 3-й столбец
data_an['debt_category'] = data_an['debt'] # запишем в 3-й столбец все данные столбца 'debt'

# заменим в 3-м столбце 0 и 1 на слова 'clear'(без задолженности) и 'debt'(с задолженностью)

replace_values = {0: 'clear', 1: 'debt'}
data_an = data_an.replace({'debt_category': replace_values})

# выведем уникальные значения и подсчитаем их количество во всех столбцах, а также исходную таблицу

print(data_an['children'].value_counts())
print()
print(data_an['debt'].value_counts())
print()
print(data_an['debt_category'].value_counts())
print()
data_an.head()
# Out:
# 0    14107
# 1     4809
# 2     2052
# 3      330
# 4       41
# 5        9
# Name: children, dtype: int64
#
# 0    19616
# 1     1732
# Name: debt, dtype: int64
#
# clear    19616
# debt      1732
# Name: debt_category, dtype: int64
#    children  debt debt_category
# 0         1     0         clear
# 1         1     0         clear
# 2         0     0         clear
# 3         3     0         clear
# 4         0     0         clear

# %%
# сгруппируем число заёмщиков по количеству детей и отсутствию/наличию задолженности

group_children = data_an.groupby(['children', 'debt_category']).agg({'debt': 'count'})
display(group_children)
# Out:
#                          debt
# children debt_category
# 0        clear          13044
#          debt            1063
# 1        clear           4365
#          debt             444
# 2        clear           1858
#          debt             194
# 3        clear            303
#          debt              27
# 4        clear             37
#          debt               4
# 5        clear              9

# %% [markdown]
# *По абсолютным цифрам больше всего должников в категории, не имеющих детей. Но поскольку это самая многочисленная категория, нельзя сделать вывод, что бездетные - самая недисциплинированная категория. Нужны относительные показатели. Их посчитаем после создания более наглядной сводной таблицы*

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Евгений, всё что выше - это твоё упражнение на вольную тему? ) Молодец на самом деле, что стараешся выйти за рамки проекта!
# </div>

# %%
# создадим сводную таблицу количества дисциплинированных и должников, исходя из количества детей

pivot_children = data_an.pivot_table(index='children', columns='debt_category', values='debt', aggfunc='count',
                                    fill_value=0)
pivot_children
# Out:
# debt_category  clear  debt
# children
# 0              13044  1063
# 1               4365   444
# 2               1858   194
# 3                303    27
# 4                 37     4
# 5                  9     0

# %%
# посчитаем процент должников в каждой категории

# создадим колонку с процентом должников по каждой категории, округлим результат, отсортируем по убыванию
pivot_children['debt %'] = pivot_children['debt'] / (pivot_children['debt'] + pivot_children['clear']) * 100
pivot_children['debt %'] = round(pivot_children['debt %'], 1)
pivot_children.sort_values('debt %', ascending=False)
# Out:
# debt_category  clear  debt  debt %
# children
# 4                 37     4     9.8
# 2               1858   194     9.5
# 1               4365   444     9.2
# 3                303    27     8.2
# 0              13044  1063     7.5
# 5                  9     0     0.0

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# **pivot_children['debt'] = pivot_children['debt'].fillna(0) #заполним пропуск, нет должников с 5-ю детьми** - это можно было сразу в коде pivot_table заполнить (параметр fill_value посмотри в документации).
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Добавил параметр fill_value в код создания pivot_table.
#         Соответсвенно, удалил
#         pivot_children['debt'] = pivot_children['debt'].fillna(0) и pivot_children = pivot_children.astype(int).
#      Как понимаю, этот параметр добавляется после первого построения таблицы, если появятся пропуски
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да Евгений, этот параметр специфичен для pivot_table и позволяет заполнить "пустоты" (NaN), образовавшиеся в результате обеъдинения данных в сводную таблицу указанным тобой значением (нулём в нашем случае).
# </div>

# %% [markdown]
#    *Проанализируем число должников по следующим подкатегориям:*
#
#    * без детей
#    * имеющие 1-2 ребёнка
#    * имеющие 3-х и более детей

# %%
def children_number(number):
    """
    Возвращает категорию по наличию детей, используя правила:
    - 'без детей', если number == 0;
    - '1-2 ребёнка', если number == 0 или number == 0;
    - 'многодетные', если number равно 3 и более.
    """
    try:
        if number == 0:
            return 'без детей'
    
        if number == 1 or number == 2:
            return '1-2 ребёнка'
    
        if number >= 3:
            return 'многодетные'
    except: 
        pass

# %%
# применим функцию children_number к столбцу 'children' нашего датафрейма
data_an['child_group'] = data_an['children'].apply(children_number)

# создадим сводную таблицу количества дисциплинированных и должников, исходя из категорий по детям
pivot_child_group = data_an.pivot_table(index='child_group', columns='debt_category', values='debt', aggfunc='count')

# создадим колонку с процентом должников по каждой категории, округлим результат, отсортируем по убыванию
pivot_child_group['debt %'] = pivot_child_group['debt'] / (pivot_child_group['debt'] + pivot_child_group['clear']) * 100
pivot_child_group['debt %'] = round(pivot_child_group['debt %'], 1)
pivot_child_group.sort_values('debt %', ascending=False)
# Out:
# debt_category  clear  debt  debt %
# child_group
# 1-2 ребёнка     6223   638     9.3
# многодетные      349    31     8.2
# без детей      13044  1063     7.5

# %% [markdown]
# **Вывод:**
#
#  *Исходя из сводных данных обеих таблиц, чётко видно, что самая дисциплинированная категория в плане погашения долга - это заёмщики без детей. Больше всего должников в категории с одним-двумя детьми, что неудивительно, ибо расходы растут. В то же время многодетные семьи - более дисциплинированная категория, чем с одним-двумя детьми, что можно объяснить более качественным планированием семейного бюджета, а, возможно, и большим количеством льгот, чем у малодетных семей.*
#
#    *Наличие 1-2 детей увеличивает вероятность невозврата кредита по сравнению с неимеющими детей, но при рождении последующих детей доля невозврата уменьшается.*

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Да, конечно «разбег» между цифрами мал. Возможно, что в рамках имеющихся данных сделать вывод о том, что семьи с детьми относительно семей без оных имеют какие-то задержки в выплатах кредитов нельзя. Слишком уж близки доли, чуть измениться выборка и значения могут измениться в другую сторону. То есть можно сделать вывод, что сколь угодно значимой разницы между группами нет.
#
# Но если считать, что **любая** разница между группами есть повод для «разделения» классов, то я бы сделал такой вывод: кредитополучатели без детей являются более ответственными, чем клиенты, у которых есть дети. Видимо, наличие ребенка накладывает на клиента дополнительные финансовое бремя (обязательства) и клиенты либо менее ответственно относятся к своим кредитным обязательствам, либо не имеют возможности в срок оплачивать обязательства.
#
# Верно «пойман» и тот момент, что по некоторым группам заемщиков у нас недостаточно данных. Говорят, что выборка не сбалансирована, классы в выборке имеют разные размеры.
#
# **но при рождении последующих детей доля невозврата уменьшается** - возможно, что поначалу рождение ребенка — это некий шок, влияющий на исполнение финансовых обязательств. В то время как для семей с большим количеством детей - дети стали обыденностью))) </div>

# %% [markdown]
# **Задание 20. Есть ли зависимость между семейным положением и возвратом кредита в срок?**

# %%
# скопируем столбцы 'family_status' и 'family_status_id' из таблицы data
data_an['family_status'] = data['family_status']
data_an['family_status_id'] = data['family_status_id']

# подсчитаем количество уникальных значений в новых столбцах, выведем таблицу
print(data_an['family_status'].value_counts())
print()
print(data_an['family_status_id'].value_counts())
print()
data_an.head()
# Out:
# женат / замужем          12266
# гражданский брак          4146
# Не женат / не замужем     2796
# в разводе                 1189
# вдовец / вдова             951
# Name: family_status, dtype: int64
#
# 0    12266
# 1     4146
# 4     2796
# 3     1189
# 2      951
# Name: family_status_id, dtype: int64
#    children  debt debt_category  child_group     family_status  \
# 0         1     0         clear  1-2 ребёнка   женат / замужем
# 1         1     0         clear  1-2 ребёнка   женат / замужем
# 2         0     0         clear    без детей   женат / замужем
# 3         3     0         clear  многодетные   женат / замужем
# 4         0     0         clear    без детей  гражданский брак
#
#    family_status_id
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 1

# %%
# чтобы убедиться, что все 'family_status_id' соответствуют своему 'family_status', сделаем группировку по ним
display(data_an.groupby(['family_status', 'family_status_id']).agg({'debt': 'count'}))

#заодно приведем к нижнему регистру 'Не женат / не замужем'
data_an['family_status'] = data_an['family_status'].str.lower()
# Out:
#                                          debt
# family_status         family_status_id
# Не женат / не замужем 4                  2796
# в разводе             3                  1189
# вдовец / вдова        2                   951
# гражданский брак      1                  4146
# женат / замужем       0                 12266

# %%
# создадим сводную таблицу количества дисциплинированных и должников, исходя из семейного положения

pivot_family = data_an.pivot_table(index='family_status', columns='debt_category', values='debt', aggfunc='count')
pivot_family
# Out:
# debt_category          clear  debt
# family_status
# в разводе               1105    84
# вдовец / вдова           888    63
# гражданский брак        3761   385
# женат / замужем        11339   927
# не женат / не замужем   2523   273

# %% [markdown]
# *Абсолютные цифры говорят о том, что неженатые/незамужние явно лучше возвращают кредит, чем семейные. Подтвердится ли на относительных цифрах?*

# %%
# посчитаем процент должников в каждой семейной категории, создадим новую колонку, округлим результат, отсортируем по убыванию

pivot_family['debt %'] = pivot_family['debt'] / (pivot_family['debt'] + pivot_family['clear']) * 100
pivot_family['debt %'] = round(pivot_family['debt %'], 1)
pivot_family.sort_values('debt %', ascending=False)
# Out:
# debt_category          clear  debt  debt %
# family_status
# не женат / не замужем   2523   273     9.8
# гражданский брак        3761   385     9.3
# женат / замужем        11339   927     7.6
# в разводе               1105    84     7.1
# вдовец / вдова           888    63     6.6

# %% [markdown]
# *Семейные категории показывают средний результат по наличию задолженности, а одиночные как дисциплинированные, так и с самой высокой долей задолженности. Логично разделить категории семейного статуса на следующие две подкатегории:*
#
#    * семейные (женат/замужем и гражданский брак)
#    * одиночки (остальные категории)

# %%
def single_double(status):
    """
    Возвращает категорию семейного или одиночки, используя правила:
    - 'семейные', если status - 'женат / замужем' или 'гражданский брак';
    - 'одиночки', если status - 'не женат / не замужем', 'в разводе' или 'вдовец / вдова'
    """
    try:
        if status == 'женат / замужем' or status == 'гражданский брак':
            return 'семейные'
    
        elif status == 'не женат / не замужем' or status == 'в разводе' or \
            status == 'вдовец / вдова':
            return 'одиночки'
        else: return 'не определён'
    except: 
        return 'не определён'

# %%
# применим функцию single_double к столбцу 'family_status' нашего датафрейма
data_an['family_group'] = data_an['family_status'].apply(single_double)

# создадим сводную таблицу количества дисциплинированных и должников, исходя из категорий семейного статуса
pivot_family_group = data_an.pivot_table(index='family_group', columns='debt_category', values='debt', aggfunc='count')

# создадим колонку с процентом должников по каждой категории, округлим результат, отсортируем по убыванию
pivot_family_group['debt %'] = pivot_family_group['debt'] / (pivot_family_group['debt'] + pivot_family_group['clear']) * 100
pivot_family_group['debt %'] = round(pivot_family_group['debt %'], 1)
pivot_family_group.sort_values('debt %', ascending=False)
# Out:
# debt_category  clear  debt  debt %
# family_group
# одиночки        4516   420     8.5
# семейные       15100  1312     8.0

# %% [markdown]
# **Вывод:**
#
# *В целом, семейные и одиночные домохозяйства почти одинаково возвращают кредиты в срок, разница в 0.5 процентных пункта. Однако, холостые люди и не состоящие в официальных отношениях в целом хуже возвращают кредиты, чем семейные. Самые надёжные в плане возврата кредитов  - одинокие, но при этом ранее бывшие в официальных семейных отношениях.*

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Здесь верно. Кредитному отделу следует с осторожностью относиться к клиентам, которые не состоят или не состояли в браке. Согласно данным такие клиенты менее ответственные. Получается, что узаконенные отношения ведут к более ответственному отношению к своим обязательствам. Ну вроде как совпадает со здравым смыслом - семейные люди более скрупулёзно берегут свой семейное спокойствие и несут за него ответственность.
#
# Также верно «пойман» момент, что у нас недостаточно данных. </div>

# %% [markdown]
# **Задание 21. Есть ли зависимость между уровнем дохода и возвратом кредита в срок?**

# %%
# скопируем категоризированный ранее столбец 'total_income_category' из таблицы data
data_an['total_income_category'] = data['total_income_category']

# посмотрим количество уникальных значений (диапазонов дохода) в 'total_income_category', выведем таблицу
print(data_an['total_income_category'].value_counts())
print()
data_an.head()
# Out:
# C    15938
# B     5014
# D      349
# A       25
# E       22
# Name: total_income_category, dtype: int64
#    children  debt debt_category  child_group     family_status  \
# 0         1     0         clear  1-2 ребёнка   женат / замужем
# 1         1     0         clear  1-2 ребёнка   женат / замужем
# 2         0     0         clear    без детей   женат / замужем
# 3         3     0         clear  многодетные   женат / замужем
# 4         0     0         clear    без детей  гражданский брак
#
#    family_status_id family_group total_income_category
# 0                 0     семейные                     B
# 1                 0     семейные                     C
# 2                 0     семейные                     C
# 3                 0     семейные                     B
# 4                 1     семейные                     C

# %%
# заменим категории в столбце 'total_income_category' на более понятные диапазоны
replace = {'A': '1 000 001 и выше', 'B': '200 001–1 000 000', 'C': '50 001–200 000', 'D': '30 001–50 000', 'E': 'до 30000'}
data_an = data_an.replace({'total_income_category': replace})
data_an
# Out:
#        children  debt debt_category  child_group     family_status  \
# 0             1     0         clear  1-2 ребёнка   женат / замужем
# 1             1     0         clear  1-2 ребёнка   женат / замужем
# 2             0     0         clear    без детей   женат / замужем
# 3             3     0         clear  многодетные   женат / замужем
# 4             0     0         clear    без детей  гражданский брак
# ...         ...   ...           ...          ...               ...
# 21520         1     0         clear  1-2 ребёнка  гражданский брак
# 21521         0     0         clear    без детей   женат / замужем
# 21522         1     1          debt  1-2 ребёнка  гражданский брак
# 21523         3     1          debt  многодетные   женат / замужем
# 21524         2     0         clear  1-2 ребёнка   женат / замужем
#
#        family_status_id family_group total_income_category
# 0                     0     семейные     200 001–1 000 000
# ...

# %%
# создадим сводную таблицу количества лиц с определенным доходом, в зависимости от имевшейся задолженности

pivot_income = data_an.pivot_table(index='total_income_category', columns='debt_category', values='debt', aggfunc='count')
pivot_income
# Out:
# debt_category          clear  debt
# total_income_category
# 1 000 001 и выше          23     2
# 200 001–1 000 000       4660   354
# 30 001–50 000            328    21
# 50 001–200 000         14585  1353
# до 30000                  20     2

# %%
# посчитаем процент должников в каждой категории дохода, создадим новую колонку, округлим результат, отсортируем по убыванию

pivot_income['debt %'] = pivot_income['debt'] / (pivot_income['debt'] + pivot_income['clear']) * 100
pivot_income['debt %'] = round(pivot_income['debt %'], 1)
pivot_income.sort_values('debt %', ascending=False)
# Out:
# debt_category          clear  debt  debt %
# total_income_category
# до 30000                  20     2     9.1
# 50 001–200 000         14585  1353     8.5
# 1 000 001 и выше          23     2     8.0
# 200 001–1 000 000       4660   354     7.1
# 30 001–50 000            328    21     6.0

# %% [markdown]
# *Из таблицы понятно, что низкие уровни дохода увеличивают вероятность задолженности, при этом заёмщики с доходами чуть выше минимальных самые дисциплинированные. Однако, данная категоризация не слишком удачна, сильный перекос в сторону одной из групп. Сделаем другую категоризацию, использовав функцию одной из предыдущих задач*

# %%
def categorize_income_2(income):
    """
    Разбивает категории доходов на следующие группы:
    - 'до 70 000' рублей,
    - 'от 70 001 до 100 000' рублей
    - 'от 100 001 до 150 000' рублей
    - 'от 150 001 до 300 000' рублей
    - 'свыше 300 001' рублей
    """
    try:
        if 0 <= income <= 70000:
            return 'до 70 000'
        elif 70001 <= income <= 100000:
            return 'от 70 001 до 100 000'
        elif 100001 <= income <= 150000:
            return 'от 100 001 до 150 000'
        elif 150001 <= income <= 300000:
            return 'от 150 001 до 300 000'
        elif income >= 300001:
            return 'свыше 300 001'
    except:
        pass

# %%
# скопируем столбец 'total_income' из таблицы data
data_an['total_income'] = data['total_income']

# применим функцию categorize_income_2 к столбцу 'total_income' нашего датафрейма
data_an['total_inc_cat_new'] = data_an['total_income'].apply(categorize_income_2)

# создадим сводную таблицу количества лиц с новыми уровнями доходов, в зависимости от задолженности
pivot_income_new = data_an.pivot_table(index='total_inc_cat_new', columns='debt_category', values='debt', aggfunc='count')

# посчитаем процент должников в каждой категории дохода, создадим новую колонку, округлим результат, отсортируем по убыванию

pivot_income_new['debt %'] = pivot_income_new['debt'] / (pivot_income_new['debt'] + pivot_income_new['clear']) * 100
pivot_income_new['debt %'] = round(pivot_income_new['debt %'], 1)
pivot_income_new.sort_values('debt %', ascending=False)
# Out:
# debt_category          clear  debt  debt %
# total_inc_cat_new
# от 100 001 до 150 000   6506   619     8.7
# от 70 001 до 100 000    2727   253     8.5
# от 150 001 до 300 000   7652   653     7.9
# свыше 300 001           1368   106     7.2
# до 70 000               1363   101     6.9

# %% [markdown]
# **Вывод:**
#
# *Как ни странно, низкий уровень дохода вовсе не предполагает высокий процент задолженности (невозврата). Люди с высокими и низкими доходами меньше всего генерируют задолженности. Высокие доходы предполагают меньшую задолженность, и человек с доходами ниже 70000 рублей в месяц, возможно, разумно подходит к вопросу планирования суммы кредита и построения расходов. Наиболее рисковая группа - с доходами от 70000 до 150000 рублей, в этом диапазоне дохода процент должников самый высокий. Предположительно, люди не совсем адекватно соотносят суммы кредита и риски потери источника дохода выше среднего.*

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Исходя из здравого смысла логично предположить, что чаще всего должниками становятся люди с небольшим доходом, которым финансовые проблемы не позволяют вовремя осуществлять платежи. Но глядя на наши результаты лично мой вывод таков: выборка по заемщикам, как с наименьшим доходом, так и с наибольшим крайне недостаточна для формирования однозначных выводов. Можно думать, что E-категория самая низкооплачиваемая не может корректно распоряжаться деньгами и «влезает» в кредиты, но тогда неясно почему у А-категории также достаточно высокий процент задолженности. В общем вывод по группам А и Е неочевиден, мало данных.
#
# Если же взять для анализа только группы В, С и D, то по полученным данным не наблюдаем зависимости "те кто получает больше ЗП, лучше возвращает кредит». В целом это логично, так как материальный достаток - не единственная переменная которая влияет на качество кредитной истории.</div>

# %% [markdown]
# **Задание 22. Как разные цели кредита влияют на его возврат в срок?**

# %%
# скопируем категоризированный ранее столбец 'purpose_category' из таблицы data
data_an['purpose_category'] = data['purpose_category']

# посмотрим количество уникальных целей кредита в 'purpose_category', выведем таблицу
print(data_an['purpose_category'].value_counts())
print()
data_an.head()
# Out:
# операции с недвижимостью    10754
# операции с автомобилем       4281
# получение образования        3989
# проведение свадьбы           2324
# Name: purpose_category, dtype: int64
#    children  debt debt_category  child_group     family_status  \
# 0         1     0         clear  1-2 ребёнка   женат / замужем
# 1         1     0         clear  1-2 ребёнка   женат / замужем
# 2         0     0         clear    без детей   женат / замужем
# 3         3     0         clear  многодетные   женат / замужем
# 4         0     0         clear    без детей  гражданский брак
#
#    family_status_id family_group total_income_category  total_income  \
# 0                 0     семейные     200 001–1 000 000        253875
# 1                 0     семейные        50 001–200 000        112080
# 2                 0     семейные        50 001–200 000        145885
# 3                 0     семейные     200 001–1 000 000        267628
# ...

# %%
# создадим сводную таблицу целей кредита и задолженности / её отсутствия

pivot_purpose = data_an.pivot_table(index='purpose_category', columns='debt_category', values='debt', aggfunc='count')
pivot_purpose
# Out:
# debt_category             clear  debt
# purpose_category
# операции с автомобилем     3881   400
# операции с недвижимостью   9974   780
# получение образования      3620   369
# проведение свадьбы         2141   183

# %% [markdown]
# *Сильного разброса в данных нет, категоризация по целям вполне адекватная*

# %%
# посчитаем процент должников по каждой цели кредита, создадим новую колонку, округлим результат, отсортируем по убыванию

pivot_purpose['debt %'] = pivot_purpose['debt'] / (pivot_purpose['debt'] + pivot_purpose['clear']) * 100
pivot_purpose['debt %'] = round(pivot_purpose['debt %'], 1)
pivot_purpose.sort_values('debt %', ascending=False)
# Out:
# debt_category             clear  debt  debt %
# purpose_category
# операции с автомобилем     3881   400     9.3
# получение образования      3620   369     9.3
# проведение свадьбы         2141   183     7.9
# операции с недвижимостью   9974   780     7.3

# %% [markdown]
# **Вывод:**
#
# *Кредиты на недвижимость - наиболее часто возращаемые и с меньшей задолженностью. Заёмщик осознает риск потери жилья, поэтому погашение таких кредитов в приоритете жизненных расходов. Далее по возвращаемости идут кредиты на проведение свадьбы, такой вид кредита, скорее всего, берут люди с доходами выше среднего. Операции с автомобилем и получение образования - цели, по которым доля проблемных кредитов составляет 9.3% от числа соответствующих целевых заёмщиков. Образование отнимает много времени, и, соответственно, меньше доход заёмщика. Автокредиты хуже возвращают из-за высоких процентов.*

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Всё подтверждается и цифрами, и здравым смыслом. Машины люди покупают в кредит гораздо дорогие, нежели могут соответствовать им своим доходом (ну кому не хочется красивую иномарку). А вот рисковать ипотечным жильём люди не хотят. Интересно конечно что с образованием не так - как правило такие кредиты берут люди мотивированные, имеющие цель впереди, да и суммы таких кредитов судя по рынку онлайн образования не так велики.</div>

# %% [markdown]
# **Задание 23. Приведите возможные причины появления пропусков в исходных данных.**

# %% [markdown]
# *Ответ:*
#
#
#   В исходной таблице `data` пропуски были в 2-х столбцах:
#
#     - число дней трудового стажа
#     - ежемесячный доход.
#
# Причём, по 2 пропуска на одной строке, то есть, если пропущено значение трудового стажа, то и пропущено значение дохода (и наоборот). Все остальные колонки строк с пропусками принимают разные значения, то есть нельзя говорить, что пропуски связаны с какой-либо категорией . Может быть несколько причин появления таких пропусков:
#
#    * клиент не предоставил данные по трудовому стажу и уровню дохода (сознательно скрыл или не было документов на момент подачи заявления на получение кредита)
#    * данные потерялись на каком-то этапе ввода в базу или выгрузки
#    * сбой в работе исходной базы, что привело к потере данных стажа и дохода определённой группы выборки
#    * банк сознательно скрыл данные о стаже и доходе ввиду особого статуса клиента

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Да, всё здраво. Эти возможные причины сразу и приходят в голову.</div>

# %% [markdown]
# **Задание 24. Объясните, почему заполнить пропуски медианным значением — лучшее решение для количественных переменных.**

# %% [markdown]
# *Ответ:*
#
# Медианное значение показывает то значение временного ряда, которое стоит в его середине, если весь ряд расставить по возрастанию значений. Данный метод заполнения хорош тем, что аномальные выбросы значений как вверх, так и вниз практически не влияют на медиану. Медианное значение, которым заполняем пропуск, наиболее близко к самым распространённым значениям временного ряда. Кроме того, если идти от противного и рассматривать другие методы заполнения пропусков, то обнаружатся ещё бо́льшие недостатки:
#
# - *заполнение средним (будут учтены аномалии, может быть значение, близкое к аномальному)*
# - *заполнение нулём (часто просто противоречит здравому смыслу)*
# - *заполнение модой (подходит для категориальных, но не для количественных переменных)*
# - *заполнение предыдущим значением (подойдет в особых случаях, если предыдущий признак не сильно отличается от заполняемого)*
#
# Вместе с тем, необходимо осознавать, что идеального способа заполнения пропусков не существует, и, например, при заполнении одним и тем же значением как медиана нарушается нормальное распределение и соответствующие его показатели.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Да, в случае, если в данных наблюдаются "выбросы", то даже небольшое их количество может сильно "перетягивать" среднее значение в большую или меньшую сторону. Медиана зачастую даёт более правдивую картину. В общем случае, в реальных "живых" проектах я рекомендую в каждом случае смотреть на то, как распределены данные.
# </div>

# %% [markdown]
# ## Общий вывод.

# %% [markdown]
# Напишите ваш общий вывод.
#
#
#  В исследовании данных банка о влиянии различных факторов на возрат кредита в срок было предложено проверить следующие гипотезы:
#
#  - **гипотеза 1**: влияет ли количество детей на возврат кредита в срок
#  - **гипотеза 2**: влияет ли семейное положение на возврат кредита в срок
#  - **гипотеза 3**: влияет ли уровень ежемесячного дохода на возврат кредита в срок
#  - **гипотеза 4**: влияют ли цели кредита на возврат его в срок
#
# В исследовании использовались данные о 21348 заёмщиках, из них 1732 имели проблемы с погашением задолженности в срок, что составляет 8.1% от всей выборки.
#
#
# * **Гипотеза 1** частично подтверждается. С уверенностью можно сказать, что рождение 1-го или 2-го ребёнка увеличивает вероятность просроченной задолженности. Так, доля проблемных кредитов среди заёмщиков, не имеющих детей, составляет 7.5%, в то время как среди имеющих 1-2 ребёнка - 9.3%. В то же время ввиду малочисленности категории с 3-мя и более детьми (380 человек против 6861 с 1-2 детьми) не представляется достоверно установить влияние рождения 3-го и последующего ребёнка на возрат кредита. Рабочая версия состоит в том, что многодетные семьи становятся более дисциплинированными в плане расходов, и доля проблемных кредитов в этой категории уменьшается по сравнению с имеющими 1-2 ребёнка (8.2% против 9.3%). Необходимо расширить выборку, чтобы подтвердить данную версию.
#
#
# * **Гипотеза 2** подтверждается в плане того, что состоящие в официальном браке (или бывшие в нём) имеют меньше проблемных кредитов, чем холостые и состоящие в неузаконенных отношениях. Так, доля проблемных кредитов среди официально женатых составляет 7.6% против 9.8% среди холостых. То есть узаконенные отношения  - стимул к более ответственным расходам. Самыми надёжными заёмщиками, пожалуй, можно назвать одиноких, но при этом бывших в официальных отношениях. Доля проблемных кредитов среди разведённых и овдовевших составляет 7.1% и 6.6% соответственно, но рекомендуется увеличить число наблюдений по данным категориям.
#
#
# * **Гипотеза 3** частично подтверждается. Если составить сбалансированную выборку по уровням доходов, то в целом зависимость "больше дохода - меньше просроченной задолженности" подтвердится, но, начиная с доходов выше средних (от 70 000 рублей). Например, доля проблемных кредитов у лиц с доходами от 70 до 100 тыс. рублей - 8.5%, а у лиц с высокими доходами (свыше 300 тыс. рублей) - 7.2%. Низкая доля задолженности у лиц с доходами до 70 тыс. рублей (6.9%) не вписывается в данную гипотезу, что может говорить, что фактор дохода - не преобладающий для своевременного погашения кредита и нуждается в дополнительном исследовании в увязке с другими факторами, например, суммой кредита.
#
#
# * **Гипотеза 4** подтверждается. Цель кредита - важный фактор для оценки его возвращаемости. Так, доля невозвратных кредитов на недвижимость меньше, чем у автокредитов (7.3% против 9.3%). И действительно, факторы потери жилья и автомобиля несоизмеримы. Можно отметить и разницу между плохими кредитами для свадебных и образовательных целей (7.9% против 9.3%). Здесь можно дополнительно поисследовать причины в увязке с сумммами кредитов и процентов по ним.
#
#
# Для дополнительной проверки гипотезы 1 и гипотезы 3 можно рекомендовать расширить выборку, а для уточнения причин распределения данных в гипотезах 3 и 4 - получить данные о суммах кредитов и процентов по ним.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий 👉</b>
#
# Финальный вывод конечно нужно более детальным сделать. Общий вывод - это изюминка твоей работы. Большинство заказчиков посмотрят сначала его (а некоторые только его). Чтобы выводы не огорошивали заказчика своей очевидностью, стоит добавить в них цифр, выводов, коэффициентов корреляций, графиков. Сделай так, чтобы вся найденная в данных информация была отражена в выводе.
#
# Твои, как аналитика, выводы - это данные ("алмаз"), которые родились из большого объёма неструктурированной, зачастую, казалось бы, несвязанной между собой информации ("горной породы").
#
# Для "не специалиста", поверь, выводы, которые ты делаешь будут казаться чем-то сродни волшебства. Эти люди "не специалисты" не будут понимать, НУ КАК ВОТ из наших табличек с кредитами можно было достать выводы, для того, чтобы спрогнозировать возврат/невозврат кредита.
#
# Но то, что они не понимают всего процесса - это не их беда. Просто они работают по-другому и мыслят другими категориями. Под "этими людьми" я здесь имею в виду топ-менеджеров, генеральных директоров и может быть ещё более высокий уровень. Их уровень понимания - это красивая и понятная им презентация в PowerPoint, с графиками бизнес показателей, с цифрами. Презентация из 3-5-10 слайдов это твоя, как аналитика "лебединая песня", те "алмазы", которые получены и облечены в ту форму, которая позволит лицам, принимающим решения принять такие зачастую многомилионной стоимости решения, которые напрямую повлияют на тот бизнес в котором ты работаешь.
# Возможный пример вывода - в виде скрина:
#
# ![image.png](attachment:image.png)</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Вывод переписал</font>
# </div>

# %% [markdown]
# # Результат ревью:
#
# Я отмечаю высокий уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python и библиотеки pandas. Использование механизмов группировки данных (groupby - он тоже в этом проекте возможен) и создания сводных таблиц (pivot_table - твой вариант) является рекомендуемым и обязательным в работе любого аналитика данных и любого проекта. Ты показываешь владение этим инструментом.
#
# Для дальнейшего совершенствования в использовании groupby, понимании расширенных концептов использования pivot_table, crosstab и далее я очень рекомендую тебе обратить внимание на следующий ресурс: https://dfedorov.spb.ru/pandas/. Рекомендуемые темы/уроки для освоения тем выше - на скрине ниже.
#
# С комментированием никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей. Ссылки из брифа проекта в нужных местах также помогают следовать за развитием событий и дают полную информацию касаемо того, что будет происходить в том или ином разделе проекта.
#
# Зелёным цветом я отметил и прокомментировал удачные и элегантные решения, на которые ты можешь опираться в будущих проектах.
#
# И всего один момент, который не позволяет мне принять твой проект в его нынешнем состоянии:
#
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Финальный вывод в таком виде - это не то, что заказчик ждет от аналитика данных. Профессионал обязан предоставить точные, четкие и корректные **прогнозы и рекомендации**, которые помогут твоей компании в реализации скорингового алгоритма. Здесь, в финальном выводе требуется максимально подробно и с цифрами описать все те инсайды в данных, которые были обнаружены в ходе выполнения проекта.</div>
#
# Этот момент требует твоего внимания. Комментарии помечены красным цветом.
#
# Подводя итог: отличная работа на самом-то деле, молодец! Уверен, что исправление вывода не вызовет у тебя сложностей. Жду доработанную версию проекта на повторное ревью.
#
# ![image.png](attachment:image.png)
